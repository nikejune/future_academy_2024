# %% [markdown]
# # 빈도 분석(명사)

# %%
from konlpy.tag import Kkma
import pandas as pd

# %%
import pandas as pd

def text_to_dataframe(file_path):
    data = []
    with open(file_path, 'r', encoding='utf-8') as file:
        for line in file:
            data.append({'Dialogue': line.strip()})

    df = pd.DataFrame(data)
    return df

file_path = "dialogue_loan.txt"
df = text_to_dataframe(file_path)
print(df)
# Out:
#                                                Dialogue
# 0                                               네 여보세요.
# 1                                              네 안녕하세요.
# 2                                 고객님 KB국민은행 김진아 대리입니다.
# 3                 네 어 목요일날 접수해주신 부분 결과 나와서 안내차 연락드렸거든요.
# 4                    잠시 통화 괜찮으시면 제가 결과 안내 도와드리도록 하겠습니다.
# ...                                                 ...
# 7933  제가 바로 포장해 놓을게요 아 아 뭐 때문에 그러냐면요 우리가 인제 박스 외관 상태...
# 7934  그냥 그냥 품목 없이 접수를 하면 접수를 안 받아줘요 사무실 쪽에서 그래서 대략적으...
# 7935                                             알겠습니다.
# 7936                                        네, 네 감사합니다.
# 7937
#
# [7938 rows x 1 columns]

# %%
kkma = Kkma()

# %%
total = []
for i in df['Dialogue'] : 
    nouns = kkma.nouns(i)
    total += nouns
total
# Out:
# ['여',
#  '고객',
#  '국민',
#  '국민은행',
#  '은행',
#  '김',
#  '대리',
#  '목요일',
#  '목요일날',
#  '날',
#  '접수',
#  '주신',
#  '부분',
#  '결과',
#  '안내',
#  '안내차',
#  '차',
#  '연락',
#  '통화',
#  '제가',
#  '결과',
#  '안내',
#  '고객',
#  '말씀',
#  '현재',
#  '결과',
#  '저희',
#  '쪽',
#  '상품',
#  '서민',
#  '구제',
#  '명목',
#  '정부',
#  '지원',
#  '출시',
#  '기존',
#  '마이너스',
#  '통장',
#  '발급',
#  '조건',
#  '그때',
#  '말씀',
#  '그때',
#  '대신',
#  '저희',
#  '쪽',
#  '고객',
#  '신용',
#  '신용대출',
#  '대출',
#  '거래',
#  '이력',
#  '토대',
#  '발급',
#  '내',
#  '상황',
#  '지금',
#  '현재',
#  '내역',
#  '결과',
#  '지금',
#  '이용',
#  '중이',
#  '주택',
#  '주택담보대출',
#  '담보',
#  '대출',
#  '부분',
#  '금융권',
#  '저금리',
#  '때문',
#  '연체',
#  '이제',
#  '신용',
#  '신용대출',
#  '거래',
#  '이력',
#  '토대',
#  '발급',
#  '내',
#  '거',
#  '면',
#  '은',
#  '고객',
#  '원금',
#  '이자',
#  '상환',
#  '내역',
#  '고객',
#  '저희',
#  '쪽',
#  '마이너스',
#  '통장',
#  '발급',
#  '내',
#  '사용',
#  '가능',
#  '뭐',
#  '판단',
#  '수',
#  '자료',
#  '말씀',
#  '주시',
#  '주시더',
#  '더',
#  '저희',
#  '쪽',
#  '마이너스',
#  '통장',
#  '발급',
#  '시',
#  '원금',
#  '이자',
#  '부분',
#  '상환',
#  '수',
#  '상환능력평가',
#  '능력',
#  '평가',
#  '미달',
#  '현재',
#  '부결',
#  '부결처리',
#  '처리',
#  '이것',
#  '뭐',
#  '대출',
#  '상황',
#  '결과',
#  '저',
#  '심',
#  '심사과',
#  '사과',
#  '기준',
#  '심사',
#  '판단',
#  '정확',
#  '말씀',
#  '수',
#  '심',
#  '심사과',
#  '사과',
#  '판단',
#  '부분',
#  '때문',
#  '결론',
#  '저',
#  '이',
#  '대출',
#  '소유',
#  '뭐',
#  '전',
#  '기존',
#  '신용',
#  '신용대출',
#  '거',
#  '사람',
#  '토대',
#  '일단',
#  '결과',
#  '이해',
#  '신용',
#  '신용대출',
#  '대출',
#  '거래',
#  '내역',
#  '토대',
#  '뭐',
#  '고객',
#  '저희',
#  '쪽',
#  '마이너스',
#  '통장',
#  '발급',
#  '경우',
#  '내',
#  '때',
#  '원금',
#  '이자',
#  '부분',
#  '상환',
#  '수',
#  '결과',
#  '제가',
#  '가능',
#  '거',
#  '상',
#  '접수',
#  '은행',
#  '국민',
#  '거기',
#  '심',
#  '심사과',
#  '사과',
#  '저',
#  '만약',
#  '마이너스',
#  '대출',
#  '상환',
#  '수',
#  '능력',
#  '판단',
#  '판단',
#  '수',
#  '여부',
#  '자료',
#  '조금',
#  '약간',
#  '부족',
#  '부족하다',
#  '하다',
#  '식',
#  '결과',
#  '저희',
#  '쪽',
#  '이제',
#  '중앙',
#  '중앙교재',
#  '교재',
#  '사용',
#  '가능',
#  '상담',
#  '접수',
#  '부분',
#  '시고',
#  '제가',
#  '때',
#  '고객',
#  '불결',
#  '불결처리',
#  '처리',
#  '뭐',
#  '4',
#  '4대',
#  '대',
#  '보험',
#  '가입',
#  '직장',
#  '재직',
#  '중이',
#  '데',
#  '이제',
#  '기간',
#  '소득',
#  '부분',
#  '편',
#  '이것',
#  '금액',
#  '마이너스',
#  '손해',
#  '발급',
#  '부',
#  '이것',
#  '부결',
#  '처리',
#  '부분',
#  '음',
#  '이해',
#  '제가',
#  '뭐',
#  '핸드폰',
#  '요금',
#  '카드',
#  '1',
#  '1번',
#  '번',
#  '저',
#  '지금',
#  '신용',
#  '신용대출',
#  '대출',
#  '3',
#  '3천만',
#  '천만',
#  '원',
#  '때',
#  '생각',
#  '서민',
#  '구제',
#  '명목',
#  '거기',
#  '때문',
#  '고객',
#  '쪽',
#  '대상자',
#  '선정',
#  '말씀',
#  '약간',
#  '조건',
#  '지',
#  '지명목',
#  '쪽',
#  '결과',
#  '이것',
#  '마이너스',
#  '통장',
#  '쪽',
#  '발급',
#  '거',
#  '쪽',
#  '발급',
#  '저희',
#  '상품',
#  '서민',
#  '구제',
#  '명목',
#  '마이너스',
#  '통장',
#  '통장상품',
#  '상품',
#  '고객',
#  '기본',
#  '본래',
#  '기본적인',
#  '적인',
#  '워크',
#  '마이너스',
#  '통장',
#  '상품',
#  '저희',
#  '쪽',
#  '발급',
#  '사용',
#  '용도',
#  '거',
#  '고객',
#  '저',
#  '지금',
#  '분양',
#  '투자',
#  '데',
#  '여기',
#  '어디',
#  '돈',
#  '뭐',
#  '주택',
#  '주택조합',
#  '조합',
#  '중간',
#  '상황',
#  '수',
#  '신용',
#  '신용대출',
#  '대출',
#  '거기',
#  '금리',
#  '한번',
#  '그때',
#  '복잡',
#  '이래',
#  '볼려',
#  '거거',
#  '고객',
#  '음',
#  '필요',
#  '저',
#  '저희',
#  '쪽',
#  '국민',
#  '국민은행',
#  '은행',
#  '상품',
#  '마이너스',
#  '통장',
#  '방법',
#  '발급',
#  '가능',
#  '수',
#  '제가',
#  '확인',
#  '음',
#  '은',
#  '제가',
#  '부분',
#  '뭐',
#  '혹시나',
#  '상품',
#  '방법',
#  '발급',
#  '가능',
#  '수',
#  '확인',
#  '저',
#  '한번',
#  '연락',
#  '제가',
#  '고객',
#  '담당',
#  '설계사',
#  '배정',
#  '때문',
#  '최대한',
#  '발급',
#  '수',
#  '노력',
#  '한번',
#  '연락',
#  '고객',
#  '감사',
#  '감사',
#  '예',
#  '220',
#  '220만',
#  '만',
#  '원',
#  '처리',
#  '가시',
#  '그거',
#  '지금',
#  '처리',
#  '가능',
#  '220',
#  '그때',
#  '그날',
#  '얘기',
#  '50',
#  '50만',
#  '만',
#  '원',
#  '원이요',
#  '이요',
#  '상담원',
#  '50',
#  '50만원',
#  '만',
#  '원',
#  '장',
#  '장바금',
#  '바',
#  '금',
#  '220',
#  '220만원',
#  '만',
#  '원',
#  '처리',
#  '거',
#  '취소',
#  '취소',
#  '이거',
#  '취소',
#  '해',
#  '수',
#  '고객',
#  '납부',
#  '거',
#  '데',
#  '한',
#  '일주일',
#  '정도',
#  '소요',
#  '예',
#  '취소',
#  '저희',
#  '쪽',
#  '취소',
#  '처리',
#  '마',
#  '1',
#  '1주일',
#  '주일',
#  '후',
#  '다음',
#  '주',
#  '월요일',
#  '정도',
#  '환급',
#  '환급처리',
#  '처리',
#  '저희',
#  '쪽',
#  '연락',
#  '주시',
#  '사이',
#  '전화',
#  '본인',
#  '인증',
#  '은',
#  '고객',
#  '거',
#  '이거',
#  '데',
#  '어플',
#  '나',
#  '전화',
#  '신안',
#  '신안캐피',
#  '캐피',
#  '핸드폰',
#  '제',
#  '본인',
#  '인증',
#  '여행',
#  '제가',
#  '이거',
#  '저',
#  '핸드폰',
#  '전화',
#  '본인',
#  '확인',
#  '리드',
#  '쿠폰',
#  '전화',
#  '때',
#  '안',
#  '본인',
#  '핸드폰',
#  '은',
#  '확인',
#  '요새',
#  '금융사',
#  '전부',
#  '다',
#  '명의',
#  '도용',
#  '본인',
#  '핸드폰',
#  '전화',
#  '확인',
#  '1',
#  '1글자',
#  '글자',
#  '정확',
#  '거',
#  '정확',
#  '주',
#  '월요일',
#  '월요일날',
#  '날',
#  '환급',
#  '거',
#  '정확',
#  '거',
#  '이거',
#  '보이스',
#  '드레',
#  '드레소',
#  '소',
#  '확인',
#  '거',
#  '본사',
#  '전화',
#  '본인',
#  '인증',
#  '고객',
#  '이',
#  '쿠폰',
#  '돈',
#  '거',
#  '차',
#  '구의',
#  '구의사항',
#  '사항',
#  '이거',
#  '녹음',
#  '취소',
#  '여',
#  '고객',
#  '담당자',
#  '박',
#  '박성률',
#  '성률',
#  '대리',
#  '그날',
#  '자동',
#  '송금',
#  '송금처리',
#  '처리',
#  '머',
#  '확인',
#  '연락',
#  '잠시',
#  '제한',
#  '최대',
#  '금액',
#  '3900',
#  '3900만원',
#  '만',
#  '원',
#  '뭐',
#  '최',
#  '최종',
#  '종',
#  '승인',
#  '금액',
#  '계좌',
#  '확인',
#  '잠시',
#  '농협',
#  '위',
#  '확인',
#  '계약서',
#  '2',
#  '2분',
#  '분',
#  '아가씨',
#  '이제',
#  '1',
#  '1분',
#  '분',
#  '고객',
#  '보관',
#  '뭐',
#  '저희',
#  '쪽',
#  '인지',
#  '등록',
#  '때문',
#  '거',
#  '같애요',
#  '이거',
#  '확인',
#  '송금',
#  '처리',
#  '도와',
#  '담당자',
#  '담당자분',
#  '분',
#  '인지',
#  '등록',
#  '절차',
#  '안내',
#  '적',
#  '있으신가요',
#  '이것',
#  '송금',
#  '직전',
#  '안내',
#  '거',
#  '양해',
#  '부탁',
#  '응',
#  '사실',
#  '지금',
#  '고객',
#  '선',
#  '최종',
#  '승인',
#  '계세',
#  '설명',
#  '인지',
#  '등록',
#  '절차',
#  '고객',
#  '담보',
#  '담보대출',
#  '대출',
#  '신용',
#  '신용대출',
#  '마이너스',
#  '마이너스통장',
#  '통장',
#  '햇살',
#  '상품',
#  '자체',
#  '요',
#  '금리',
#  '적용',
#  '때문',
#  '이제',
#  '변경',
#  '사안',
#  '응',
#  '시간',
#  '이제',
#  '금리',
#  '고정적',
#  '다행',
#  '대부분',
#  '거',
#  '때문',
#  '부분',
#  '고객',
#  '피해',
#  '이제',
#  '금융',
#  '금융법이',
#  '법이',
#  '개정',
#  '거',
#  '기존',
#  '고금리',
#  '대출',
#  '상',
#  '계약서',
#  '연체',
#  '경우',
#  '연체금리',
#  '금리',
#  '최대',
#  '69',
#  '69프로',
#  '프로',
#  '사채',
#  '수준',
#  '거',
#  '때문',
#  '절차',
#  '고객',
#  '상환',
#  '기간',
#  '동안',
#  '변동',
#  '금리',
#  '만기',
#  '때',
#  '확정',
#  '고정',
#  '이용',
#  '수',
#  '도움',
#  '부분',
#  '예',
#  '이해',
#  '인지세',
#  '이것',
#  '마이너스',
#  '통장',
#  '신용',
#  '신용대출',
#  '대출',
#  '협상',
#  '상품',
#  '자체',
#  '적용',
#  '금리',
#  '부대',
#  '이것',
#  '변동',
#  '변동사항',
#  '사항',
#  '시간',
#  '금리',
#  '낮으거',
#  '고정',
#  '다행',
#  '대부분',
#  '대부분',
#  '고객',
#  '피해',
#  '인제',
#  '개정',
#  '기존',
#  '공',
#  '공금리',
#  '금리',
#  '대출',
#  '상품',
#  '자체',
#  '계약서',
#  '연체',
#  '경우',
#  '이제',
#  '최대',
#  '60',
#  '60프로',
#  '프로',
#  '예',
#  '사채',
#  '수준',
#  '이제',
#  '금리',
#  '때문',
#  '절차',
#  '거기',
#  '사용',
#  '상환',
#  '기간',
#  '동안',
#  '변동',
#  '변동금리',
#  '만기',
#  '때',
#  '확정',
#  '고정',
#  '고정금리',
#  '이용',
#  '수',
#  '도움',
#  '드릴려',
#  '부분',
#  '이행',
#  '대신',
#  '방법',
#  '부분',
#  '확인',
#  '저희',
#  '쪽',
#  '이제',
#  '송금',
#  '처리',
#  '1',
#  '1시간',
#  '시간',
#  '내',
#  '도움',
#  '수',
#  '인지세',
#  '고객',
#  '대차',
#  '이제',
#  '대출',
#  '자금',
#  '10',
#  '10프로',
#  '프로',
#  '진행',
#  '금액',
#  '390',
#  '390만원',
#  '만',
#  '원',
#  '확인',
#  '임기',
#  '등록',
#  '자체',
#  '이제',
#  '부담',
#  '대출',
#  '결과',
#  '정확',
#  '보호',
#  '수',
#  '금액',
#  '때문',
#  '인제',
#  '안전',
#  '대출금',
#  '수령',
#  '전액',
#  '환급',
#  '전',
#  '연체',
#  '이력',
#  '지금',
#  '자금',
#  '그거',
#  '연체이자',
#  '이자',
#  '때문',
#  '저',
#  '그때',
#  '돈',
#  '이것',
#  '저희',
#  '쪽',
#  '이',
#  '등록',
#  '절차',
#  '앞',
#  '지금',
#  '자금',
#  '수',
#  '상황',
#  '원래',
#  '제가',
#  '자동',
#  '송',
#  '송구권',
#  '구권',
#  '도움',
#  '부분',
#  '때문',
#  '지금',
#  '송금',
#  '거',
#  '고',
#  '그',
#  '그거',
#  '대',
#  '낙서',
#  '부분',
#  '저희',
#  '쪽',
#  '인지세',
#  '확인',
#  '본인',
#  '앞',
#  '자금',
#  '수',
#  '세',
#  '이것',
#  '금융',
#  '금융법이',
#  '법이',
#  '개정',
#  '이제',
#  '금융감동사회',
#  '감동',
#  '사회',
#  '이적',
#  '확인',
#  '저희',
#  '쪽',
#  '자금',
#  '수',
#  '부분',
#  '환급',
#  '수',
#  '거기',
#  '때문',
#  '이거',
#  '저희',
#  '쪽',
#  '납부',
#  '고객',
#  '자금',
#  '나가시',
#  '은',
#  '사용',
#  '사용보호소',
#  '보호소',
#  '방문',
#  '서류',
#  '제출',
#  '30',
#  '30분',
#  '분',
#  '1',
#  '1시간',
#  '시간',
#  '내',
#  '거',
#  '예',
#  '계세',
#  '납부',
#  '저희',
#  '경우',
#  '현직',
#  '계좌',
#  '세무',
#  '세무대행표',
#  '대행',
#  '표',
#  '통해',
#  '저',
#  '담당',
#  '담당자랑',
#  '자랑',
#  '한번',
#  '얘기',
#  '수록',
#  '확인',
#  '동일',
#  '대출',
#  '자금',
#  '응',
#  '응',
#  '이제',
#  '제가',
#  '전산',
#  '담당자',
#  '터',
#  '담당',
#  '담당자랑',
#  '자랑',
#  '한번',
#  '통화',
#  '야',
#  '전화',
#  '계세',
#  '1',
#  '1가지',
#  '가지',
#  '예',
#  '뭐',
#  '저',
#  '고객',
#  '나중',
#  '지금',
#  '여',
#  '지금',
#  '2',
#  '2분',
#  '분',
#  '임신',
#  '지급',
#  '제가',
#  '부분',
#  '고객',
#  '말씀',
#  '대로',
#  '전산',
#  '삭제',
#  '만약',
#  '취소',
#  '저번',
#  '주',
#  '환불',
#  '환불금',
#  '금',
#  '자체',
#  '손실',
#  '발생',
#  '고객',
#  '예',
#  '그거',
#  '어디',
#  '가면',
#  '전',
#  '전천지',
#  ...]

# %%
from collections import Counter # 빈도분석

Counter(total).most_common(100) # 가장 많이 나온 단어 TOP 100
# Out:
# [('고객', 1550),
#  ('거', 985),
#  ('저희', 945),
#  ('예', 823),
#  ('뭐', 766),
#  ('저', 712),
#  ('제가', 577),
#  ('지금', 559),
#  ('대출', 484),
#  ('수', 439),
#  ('전화', 438),
#  ('원', 433),
#  ('쪽', 431),
#  ('은행', 417),
#  ('진행', 359),
#  ('처리', 355),
#  ('1', 343),
#  ('만', 339),
#  ('부분', 338),
#  ('때문', 323),
#  ('확인', 300),
#  ('자금', 298),
#  ('분', 287),
#  ('은', 276),
#  ('상환', 269),
#  ('가능', 249),
#  ('말씀', 248),
#  ('이거', 234),
#  ('이제', 232),
#  ('카드', 230),
#  ('2', 230),
#  ('이것', 220),
#  ('정도', 205),
#  ('계좌', 203),
#  ('연락', 200),
#  ('그거', 200),
#  ('3', 195),
#  ('돈', 185),
#  ('건', 180),
#  ('때', 176),
#  ('통장', 174),
#  ('번호', 173),
#  ('일단', 166),
#  ('금액', 166),
#  ('일', 166),
#  ('거기', 164),
#  ('한번', 152),
#  ('시', 150),
#  ('얘기', 148),
#  ('여', 146),
#  ('경우', 145),
#  ('신용', 142),
#  ('시간', 140),
#  ('번', 139),
#  ('우리', 139),
#  ('본인', 138),
#  ('납부', 137),
#  ('전산', 134),
#  ('나', 132),
#  ('서류', 131),
#  ('5', 131),
#  ('필요', 130),
#  ('사용', 128),
#  ('오늘', 127),
#  ('접수', 126),
#  ('그쪽', 126),
#  ('통화', 125),
#  ('말', 122),
#  ('한도', 120),
#  ('발급', 119),
#  ('만약', 115),
#  ('금리', 111),
#  ('담당자', 111),
#  ('이용', 110),
#  ('승인', 109),
#  ('안', 108),
#  ('입금', 106),
#  ('4', 105),
#  ('잠시', 105),
#  ('전', 104),
#  ('농협', 102),
#  ('이요', 101),
#  ('천만', 100),
#  ('프로', 99),
#  ('국민', 98),
#  ('어디', 98),
#  ('그', 98),
#  ('하나', 98),
#  ('심사', 96),
#  ('내', 95),
#  ('금융', 95),
#  ('데', 94),
#  ('감사', 94),
#  ('신청', 94),
#  ('상품', 93),
#  ('생각', 92),
#  ('이상', 91),
#  ('안내', 90),
#  ('중', 89),
#  ('거래', 88)]

# %%
dic = Counter(total)
dic
# Out:
# Counter({'여': 146,
#          '고객': 1550,
#          '국민': 98,
#          '국민은행': 54,
#          '은행': 417,
#          '김': 40,
#          '대리': 61,
#          '목요일': 4,
#          '목요일날': 1,
#          '날': 44,
#          '접수': 126,
#          '주신': 52,
#          '부분': 338,
#          '결과': 46,
#          '안내': 90,
#          '안내차': 4,
#          '차': 60,
#          '연락': 200,
#          '통화': 125,
#          '제가': 577,
#          '말씀': 248,
#          '현재': 32,
#          '저희': 945,
#          '쪽': 431,
#          '상품': 93,
#          '서민': 27,
#          '구제': 3,
#          '명목': 3,
#          '정부': 46,
#          '지원': 68,
#          '출시': 7,
#          '기존': 47,
#          '마이너스': 78,
#          '통장': 174,
#          '발급': 119,
#          '조건': 41,
#          '그때': 55,
#          '대신': 22,
#          '신용': 142,
#          '신용대출': 26,
#          '대출': 484,
#          '거래': 88,
#          '이력': 16,
#          '토대': 10,
#          '내': 95,
#          '상황': 76,
#          '지금': 559,
#          '내역': 58,
#          '이용': 110,
#          '중이': 37,
#          '주택': 6,
#          '주택담보대출': 1,
#          '담보': 15,
#          '금융권': 41,
#          '저금리': 16,
#          '때문': 323,
#          '연체': 62,
#          '이제': 232,
#          '거': 985,
#          '면': 52,
#          '은': 276,
#          '원금': 29,
#          '이자': 76,
#          '상환': 269,
#          '사용': 128,
#          '가능': 249,
#          '뭐': 766,
#          '판단': 14,
#          '수': 439,
#          '자료': 13,
#          '주시': 43,
#          '주시더': 1,
#          '더': 1,
#          '시': 150,
#          '상환능력평가': 6,
#          '능력': 21,
#          '평가': 23,
#          '미달': 9,
#          '부결': 38,
#          '부결처리': 5,
#          '처리': 355,
#          '이것': 220,
#          '저': 712,
#          '심': 27,
#          '심사과': 20,
#          '사과': 27,
#          '기준': 8,
#          '심사': 96,
#          '정확': 42,
#          '결론': 7,
#          '이': 62,
#          '소유': 1,
#          '전': 104,
#          '사람': 83,
#          '일단': 166,
#          '이해': 60,
#          '경우': 145,
#          '때': 176,
#          '상': 38,
#          '거기': 164,
#          '만약': 115,
#          '여부': 6,
#          '조금': 39,
#          '약간': 11,
#          '부족': 19,
#          '부족하다': 3,
#          '하다': 22,
#          '식': 27,
#          '중앙': 3,
#          '중앙교재': 1,
#          '교재': 1,
#          '상담': 71,
#          '시고': 34,
#          '불결': 2,
#          '불결처리': 1,
#          '4': 105,
#          '4대': 11,
#          '대': 48,
#          '보험': 34,
#          '가입': 18,
#          '직장': 22,
#          '재직': 5,
#          '데': 94,
#          '기간': 60,
#          '소득': 28,
#          '편': 4,
#          '금액': 166,
#          '손해': 6,
#          '부': 24,
#          '음': 32,
#          '핸드폰': 32,
#          '요금': 10,
#          '카드': 230,
#          '1': 343,
#          '1번': 83,
#          '번': 139,
#          '3': 195,
#          '3천만': 13,
#          '천만': 100,
#          '원': 433,
#          '생각': 92,
#          '대상자': 3,
#          '선정': 3,
#          '지': 25,
#          '지명목': 1,
#          '통장상품': 1,
#          '기본': 9,
#          '본래': 1,
#          '기본적인': 3,
#          '적인': 10,
#          '워크': 1,
#          '용도': 20,
#          '분양': 1,
#          '투자': 13,
#          '여기': 74,
#          '어디': 98,
#          '돈': 185,
#          '주택조합': 1,
#          '조합': 2,
#          '중간': 21,
#          '금리': 111,
#          '한번': 152,
#          '복잡': 4,
#          '이래': 9,
#          '볼려': 1,
#          '거거': 43,
#          '필요': 130,
#          '방법': 83,
#          '확인': 300,
#          '혹시나': 4,
#          '담당': 31,
#          '설계사': 2,
#          '배정': 39,
#          '최대한': 27,
#          '노력': 2,
#          '감사': 94,
#          '예': 823,
#          '220': 4,
#          '220만': 1,
#          '만': 339,
#          '가시': 11,
#          '그거': 200,
#          '그날': 6,
#          '얘기': 148,
#          '50': 22,
#          '50만': 5,
#          '원이요': 8,
#          '이요': 101,
#          '상담원': 17,
#          '50만원': 4,
#          '장': 15,
#          '장바금': 1,
#          '바': 27,
#          '금': 39,
#          '220만원': 1,
#          '취소': 45,
#          '이거': 234,
#          '해': 36,
#          '납부': 137,
#          '한': 12,
#          '일주일': 4,
#          '정도': 205,
#          '소요': 18,
#          '마': 9,
#          '1주일': 11,
#          '주일': 12,
#          '후': 40,
#          '다음': 71,
#          '주': 27,
#          '월요일': 33,
#          '환급': 45,
#          '환급처리': 10,
#          '사이': 16,
#          '전화': 438,
#          '본인': 138,
#          '인증': 20,
#          '어플': 5,
#          '나': 132,
#          '신안': 1,
#          '신안캐피': 1,
#          '캐피': 2,
#          '제': 15,
#          '여행': 2,
#          '리드': 6,
#          '쿠폰': 4,
#          '안': 108,
#          '요새': 1,
#          '금융사': 46,
#          '전부': 13,
#          '다': 9,
#          '명의': 49,
#          '도용': 7,
#          '1글자': 1,
#          '글자': 3,
#          '월요일날': 10,
#          '보이스': 21,
#          '드레': 1,
#          '드레소': 1,
#          '소': 7,
#          '본사': 30,
#          '구의': 1,
#          '구의사항': 1,
#          '사항': 40,
#          '녹음': 12,
#          '담당자': 111,
#          '박': 8,
#          '박성률': 1,
#          '성률': 1,
#          '자동': 27,
#          '송금': 51,
#          '송금처리': 6,
#          '머': 1,
#          '잠시': 105,
#          '제한': 10,
#          '최대': 45,
#          '3900': 1,
#          '3900만원': 1,
#          '최': 10,
#          '최종': 24,
#          '종': 3,
#          '승인': 109,
#          '계좌': 203,
#          '농협': 102,
#          '위': 20,
#          '계약서': 29,
#          '2': 230,
#          '2분': 8,
#          '분': 287,
#          '아가씨': 1,
#          '1분': 5,
#          '보관': 4,
#          '인지': 12,
#          '등록': 35,
#          '같애요': 21,
#          '도와': 18,
#          '담당자분': 10,
#          '절차': 26,
#          '적': 22,
#          '있으신가요': 1,
#          '직전': 1,
#          '양해': 7,
#          '부탁': 22,
#          '응': 40,
#          '사실': 24,
#          '선': 24,
#          '계세': 20,
#          '설명': 85,
#          '담보대출': 5,
#          '마이너스통장': 8,
#          '햇살': 23,
#          '자체': 61,
#          '요': 77,
#          '적용': 19,
#          '변경': 14,
#          '사안': 2,
#          '시간': 140,
#          '고정적': 1,
#          '다행': 3,
#          '대부분': 5,
#          '피해': 14,
#          '금융': 95,
#          '금융법이': 2,
#          '법이': 3,
#          '개정': 3,
#          '고금리': 18,
#          '연체금리': 2,
#          '69': 3,
#          '69프로': 1,
#          '프로': 99,
#          '사채': 3,
#          '수준': 2,
#          '동안': 38,
#          '변동': 23,
#          '만기': 17,
#          '확정': 4,
#          '고정': 10,
#          '도움': 37,
#          '인지세': 7,
#          '협상': 1,
#          '부대': 1,
#          '변동사항': 4,
#          '낮으거': 1,
#          '인제': 15,
#          '공': 8,
#          '공금리': 1,
#          '60': 24,
#          '60프로': 1,
#          '변동금리': 1,
#          '고정금리': 7,
#          '드릴려': 3,
#          '이행': 3,
#          '1시간': 19,
#          '대차': 1,
#          '자금': 298,
#          '10': 64,
#          '10프로': 7,
#          '진행': 359,
#          '390': 1,
#          '390만원': 1,
#          '임기': 1,
#          '부담': 25,
#          '보호': 3,
#          '안전': 16,
#          '대출금': 64,
#          '수령': 41,
#          '전액': 13,
#          '연체이자': 1,
#          '앞': 61,
#          '원래': 28,
#          '송': 2,
#          '송구권': 1,
#          '구권': 1,
#          '고': 42,
#          '그': 98,
#          '낙서': 1,
#          '세': 2,
#          '금융감동사회': 1,
#          '감동': 1,
#          '사회': 6,
#          '이적': 1,
#          '나가시': 11,
#          '사용보호소': 1,
#          '보호소': 1,
#          '방문': 53,
#          '서류': 131,
#          '제출': 5,
#          '30': 36,
#          '30분': 18,
#          '현직': 1,
#          '세무': 6,
#          '세무대행표': 1,
#          '대행': 4,
#          '표': 2,
#          '통해': 10,
#          '담당자랑': 4,
#          '자랑': 6,
#          '수록': 1,
#          '동일': 14,
#          '전산': 134,
#          '터': 67,
#          '야': 14,
#          '1가지': 14,
#          '가지': 56,
#          '나중': 36,
#          '임신': 1,
#          '지급': 35,
#          '대로': 31,
#          '삭제': 21,
#          '저번': 4,
#          '환불': 15,
#          '환불금': 1,
#          '손실': 2,
#          '발생': 52,
#          '가면': 9,
#          '전천지': 1,
#          '천지': 1,
#          '건': 180,
#          '부분이요': 3,
#          '정': 14,
#          '정산비': 1,
#          '산비': 1,
#          '습': 2,
#          '허': 3,
#          '보증': 69,
#          '보증보험료': 2,
#          '보험료': 3,
#          '교구': 1,
#          '불법': 14,
#          '편법': 18,
#          '내가': 68,
#          '부재': 3,
#          '부재지면': 1,
#          '지면': 4,
#          '처음': 59,
#          '개': 54,
#          '회비': 2,
#          '친구': 14,
#          '그것': 81,
#          '이때': 3,
#          '랬': 1,
#          '그쪽': 126,
#          '9': 41,
#          '1프로': 3,
#          '간호': 1,
#          '수수료': 40,
#          '120': 2,
#          '120만': 1,
#          '금감원': 19,
#          '신고': 57,
#          '제도': 9,
#          '공정': 5,
#          '공정전': 1,
#          '입장': 41,
#          '우리': 139,
#          '집': 20,
#          '소현': 1,
#          '현': 7,
#          '100': 34,
#          '100프로': 7,
#          '애': 32,
#          '고양이': 1,
#          '말': 122,
#          '막말': 2,
#          '아저씨': 8,
#          '잘못': 11,
#          '3자': 3,
#          '자': 19,
#          '이야기': 11,
#          '거잖아': 81,
#          '쵸': 17,
#          '법적': 18,
#          '당사자': 4,
#          '298': 1,
#          '298만': 1,
#          '27': 3,
#          '27만': 1,
#          '납득': 5,
#          '지하철': 1,
#          '전문': 6,
#          '배송': 7,
#          '업체': 34,
#          '업체구': 1,
#          '구': 24,
#          '물건': 5,
#          '법원': 6,
#          '공탁': 2,
#          '부동산': 4,
#          '자동차': 3,
#          '매매': 3,
#          '매매매입': 1,
#          '매입': 8,
#          '인테리어': 1,
#          '견적': 2,
#          '서류배송': 1,
#          '일당': 1,
#          '당일': 35,
#          '드리고': 10,
#          '1건당': 1,
#          '당': 19,
#          '5': 131,
#          '5천': 5,
#          '천': 40,
#          '일': 166,
#          '예단': 2,
#          '예물': 2,
#          '건도': 3,
#          '오시': 5,
#          '단가': 1,
#          '쎄요': 1,
#          '2만': 3,
#          '면접': 3,
#          '출구': 4,
#          '직원': 86,
#          '직원분': 13,
#          '이동': 16,
#          '노포': 1,
#          '노포역': 1,
#          '역': 6,
#          '평': 2,
#          '평역': 1,
#          '하면': 69,
#          '신문': 2,
#          '신문역': 1,
#          '도착': 10,
#          '9시': 14,
#          '반': 25,
#          '2시': 12,
#          '출근': 12,
#          '자택': 8,
#          '지하철역': 1,
#          '일거리': 1,
#          '오늘': 127,
#          '인상': 1,
#          '인상착의': 1,
#          '착의': 2,
#          '청바지': 1,
#          '검은색': 1,
#          '티': 7,
#          '2번': 18,
#          '수당': 7,
#          '수당착의': 1,
#          '실버': 1,
#          '물류': 1,
#          '선생님': 32,
#          '비용': 64,
#          '66': 1,
#          '66만': 1,
#          '3일': 12,
#          '뒤': 30,
#          '직접적': 3,
#          '반환': 13,
#          '중': 89,
#          '언제쯤': 5,
#          '법무사': 11,
#          '사무실': 21,
#          '다가': 6,
#          '채무': 30,
#          '최선': 3,
#          '직접': 24,
#          '약': 3,
#          '약수동': 1,
#          '수동': 1,
#          '성함': 49,
#          '요리': 1,
#          '요리금': 1,
#          '이름': 51,
#          '신': 47,
#          '신가요': 10,
#          '가요': 33,
#          '인터넷': 35,
#          '뱅킹': 23,
#          '폰': 10,
#          '폰뱅킹': 3,
#          '스마트': 9,
#          '스마트폰': 4,
#          '뱅킹이요': 1,
#          '안녕': 40,
#          '현대': 25,
#          '캐피탈': 64,
#          '결제': 44,
#          '결제부서': 4,
#          '부서': 31,
#          '김고은': 1,
#          '고은': 1,
#          '과장': 30,
#          '불편': 13,
#          '개인': 55,
#          '신원': 4,
#          '확인차': 7,
#          '생년': 7,
#          '생년월일': 14,
#          '월일': 8,
#          '앞자리': 5,
#          '자리': 25,
#          '플러스': 7,
#          '계좌번호': 34,
#          '번호': 173,
#          '미안': 5,
#          '자동이체': 10,
#          '이체': 54,
#          '설정': 48,
#          '납부일은': 1,
#          '일은': 6,
#          '11': 16,
#          '11일': 3,
#          '지정': 11,
#          '2300': 7,
#          '2300만원': 3,
#          '8': 34,
#          '5년': 25,
#          '년': 85,
#          '월': 41,
#          '포함': 13,
#          '475213': 1,
#          '475213원': 1,
#          '요거': 55,
#          '증액': 12,
#          '700': 7,
#          '700만원': 2,
#          '거세': 19,
#          '연': 28,
#          '557858': 1,
#          '557858원': 1,
#          '거랑': 10,
#          '개인정보': 15,
#          '정보': 52,
#          '송금시간': 1,
#          '예약': 11,
#          '예약송금': 3,
#          '19': 5,
#          '19시': 2,
#          '20': 38,
#          '20시': 2,
#          '순번': 3,
#          '다섯': 2,
#          '번째': 19,
#          '여섯': 1,
#          '내일': 72,
#          '오전': 45,
#          '10시': 10,
#          '불가능': 9,
#          '그다음': 47,
#          '계약': 45,
#          '이체하면': 1,
#          '리': 14,
#          '대비': 4,
#          '전산상': 7,
#          '전자': 21,
#          '전달': 19,
#          '전자설명': 1,
#          '녹취': 25,
#          '녹취전화': 1,
#          '도움드릴': 1,
#          '드릴': 9,
#          '혹': 7,
#          '예약이체': 1,
#          '상태': 27,
#          '세요': 32,
#          '수고': 10,
#          '고생': 8,
#          '위로': 1,
#          '서울': 31,
#          '관리': 70,
#          '종료': 1,
#          '밥': 3,
#          '1끼': 1,
#          '끼': 2,
#          '인연': 1,
#          '퇴근': 13,
#          '김구은': 1,
#          '구은': 1,
#          '보유': 4,
#          '중이신': 6,
#          '일부': 27,
#          '공간': 3,
#          '조건부': 10,
#          '가능하다': 5,
#          '오해': 9,
#          '절대': 10,
#          '거구': 79,
#          '최소': 11,
#          '변제': 30,
#          '300': 46,
#          '300만': 19,
#          '2400': 5,
#          '2400만': 5,
#          '대환': 51,
#          '생계': 5,
#          '100만': 13,
#          '1만': 2,
#          '생계자금': 2,
#          '400': 10,
#          '400만': 4,
#          '남': 9,
#          '무관': 7,
#          '임대': 10,
#          '임대분할': 1,
#          '분할': 13,
#          '300만원': 17,
#          '무엇': 24,
#          '입금': 106,
#          '강신': 2,
#          '강신개': 1,
#          '씨': 36,
#          '환': 12,
#          '6': 64,
#          '6자리': 10,
#          '상환금액': 5,
#          '180': 2,
#          '180만원': 1,
#          '잔금': 5,
#          '메일': 1,
#          '이관': 23,
#          '이관처리': 1,
#          '누': 16,
#          '강신기': 1,
#          '기': 13,
#          '하라': 22,
#          '강': 5,
#          '강승규': 2,
#          '승규': 2,
#          '조치': 12,
#          '정상': 10,
#          '정상처리': 2,
#          '기록': 34,
#          '요청': 74,
#          '보이스피싱': 18,
#          '피': 25,
#          '싱': 19,
#          '걸': 11,
#          '캐피털': 11,
#          '요즘': 27,
#          '조심': 3,
#          '조심하라': 1,
#          '대북': 1,
#          '특별': 3,
#          '철회': 4,
#          '주민': 21,
#          '체크': 31,
#          '체크박스': 1,
#          '박스': 10,
#          '동의': 26,
#          '게': 9,
#          '고요': 18,
#          '강신규씨': 1,
#          '신규': 20,
#          '가상': 16,
#          '가상계좌신': 1,
#          '정상적': 28,
#          '염려': 1,
#          '확인처리': 1,
#          '연락처': 6,
#          '모든': 4,
#          '예외': 9,
#          '추가': 37,
#          '사유': 6,
#          '자격': 4,
#          '2달': 18,
#          '달': 62,
#          '46': 3,
#          '46만': 3,
#          '계속': 28,
#          '60일': 1,
#          '안정': 5,
#          '안정계획': 1,
#          '계획': 4,
#          '추가적': 14,
#          '당부': 2,
#          '현금': 46,
#          '현금서비스': 11,
#          '서비스': 16,
#          '추가적인': 4,
#          '대화': 3,
#          '세금': 18,
#          '소비자': 13,
#          '이상': 91,
#          '그거잖아': 1,
#          '1금융': 4,
#          '7234': 1,
#          '7234금융': 1,
#          '회원': 15,
#          '신용등급': 21,
#          '등급': 42,
#          '소비자금융권': 4,
#          '은행연합회': 10,
#          '연합회': 13,
#          '공유': 4,
#          '공유전산': 2,
#          '산하': 10,
#          '옆': 10,
#          '조회': 36,
#          '대출정보': 2,
#          '영향': 3,
#          '단기': 6,
#          '중도': 31,
#          '중도상환': 18,
#          '특성': 5,
#          '2천만': 15,
#          '3달': 8,
#          '1금융권': 4,
#          '개념': 3,
#          '새': 3,
#          '새마': 1,
#          '옷': 2,
#          '징검다리': 1,
#          '통닭': 1,
#          '61': 3,
#          '61일자': 3,
#          '일자': 7,
#          '3번째': 1,
#          '바깥': 1,
#          '3회차': 2,
#          '회': 7,
#          '마무리': 23,
#          '정리': 39,
#          '실적': 17,
#          '내용': 43,
#          '흐름': 1,
#          '확약': 1,
#          '발송': 24,
#          '걱정': 32,
#          '한도': 120,
#          '목적': 6,
#          '절대적': 1,
#          '옛날': 2,
#          '문제': 72,
#          '10년': 7,
#          '유지': 9,
#          '지네': 1,
#          '하면서': 3,
#          '7': 44,
#          '7명': 1,
#          '명': 9,
#          '시티': 4,
#          '만큼': 5,
#          '고객님': 48,
#          '님': 61,
#          '1천만': 4,
#          '대안': 19,
#          '등급상은': 1,
#          '상은': 2,
#          '후면': 1,
#          '갚으': 1,
#          '금융거래': 1,
#          '단계': 2,
#          '신용평점': 11,
#          '평점': 59,
#          '상향': 15,
#          '지실': 1,
#          '거지': 22,
#          '무조건': 2,
#          '요령': 6,
#          '위원': 8,
#          '질문': 15,
#          '주소': 18,
#          '부부': 1,
#          '선적': 1,
#          '코드': 25,
#          '선적수가': 1,
#          '수가': 3,
#          '고인': 1,
#          '하수': 2,
#          '하수진': 1,
#          '진': 6,
#          '팀장': 30,
#          '수진': 1,
#          '진짜': 9,
#          '숫자': 10,
#          '2가지': 20,
#          '중요': 28,
#          '얼마': 81,
#          '의원': 7,
#          '의무적': 2,
#          '이득': 4,
#          '주실': 13,
#          '유도': 2,
#          '라도': 12,
#          '며칠': 10,
#          '드림': 1,
#          '신청서': 4,
#          '작성': 26,
#          '주셨': 1,
#          '편의': 1,
#          '편의상': 1,
#          '대리작성': 1,
#          '대리접수': 3,
#          '임대쪽': 1,
#          '생활': 27,
#          '생활자원': 1,
#          '자원': 1,
#          '가계': 1,
#          '비교': 1,
#          '2곳': 1,
#          '곳': 24,
#          '동시': 9,
#          '저하': 6,
#          '신명': 1,
#          '인증번호': 4,
#          '고거': 10,
#          '호': 6,
#          '5분': 13,
#          '10분': 15,
#          '안쪽': 5,
#          '요번': 8,
#          '기획': 4,
#          '기획대출': 2,
#          '기획대출상품': 1,
#          '의향': 9,
#          '연유': 1,
#          '8프로': 8,
#          '개통': 1,
#          '반영': 13,
#          '옥': 2,
#          '옥수프': 1,
#          '수프': 1,
#          '필리핀': 1,
#          '마누라': 1,
#          '사망': 3,
#          '엄마': 15,
#          '상화': 1,
#          '거시기': 1,
#          '전화번호': 32,
#          '갖고': 1,
#          '장난': 6,
#          '건강': 1,
#          '너': 11,
#          '마닐라': 1,
#          '마카티': 1,
#          '카': 9,
#          '마카피': 1,
#          '카피': 1,
#          '마릴라이': 1,
#          '릴': 1,
#          '라이': 1,
#          '외출': 2,
#          '금지': 2,
#          '완전': 5,
#          '감금': 2,
#          '락': 1,
#          '락카피시티': 1,
#          '우리나라': 3,
#          '나라': 6,
#          '강남': 2,
#          '파란': 1,
#          '여행도': 1,
#          '주말': 8,
#          '이달': 2,
#          '제안': 2,
#          '누구': 14,
#          '김지연': 1,
#          '지연': 6,
#          '아이': 36,
#          '누군지': 2,
#          '군지': 2,
#          '사': 40,
#          '이대성': 1,
#          '대성': 2,
#          '신상': 2,
#          '신상캐피탈': 1,
#          '예예': 15,
#          '1700': 6,
#          '1700만': 3,
#          '60개월': 14,
#          '개월': 85,
#          '359529': 1,
#          '359529원': 1,
#          '잠깐': 25,
#          '15': 15,
#          '15만': 1,
#          '9529': 1,
#          '9529원': 1,
#          '5년이요': 2,
#          '1700만원이요': 1,
#          '2유가': 1,
#          '유가': 1,
#          '일유리': 1,
#          '유리': 3,
#          '가족': 10,
#          '결과상': 1,
#          '으': 4,
#          '나이': 15,
#          '현대캐피탈': 10,
#          '2800': 4,
#          '800': 16,
#          '800만': 7,
#          '데이터': 12,
#          '데이터상': 1,
#          '현태': 1,
#          '송금팀': 1,
#          '팀': 57,
#          '중이시고': 1,
#          '한지': 2,
#          '라': 34,
#          '면제': 5,
#          '께네': 1,
#          '대꾸': 1,
#          '나머지': 28,
#          '싹': 1,
#          '2프로': 4,
#          '도': 13,
#          '경우구': 1,
#          '변질': 3,
#          '당장': 8,
#          '금방': 1,
#          '방': 1,
#          '큰돈': 5,
#          '1500': 15,
#          '1500만': 8,
#          '1500이요': 1,
#          '공문서': 10,
#          '의뢰': 7,
#          '니': 28,
#          '낮': 5,
#          '팩스': 17,
#          '답장': 3,
#          '해라': 2,
#          '펜': 3,
#          '종이': 2,
#          '하나': 98,
#          '준비': 27,
#          ...})

# %%
#1글자 제거
dic = {key: value for key, value in dic.items() if len(key) > 1}

print(dic)
# Out:
# {'고객': 1550, '국민': 98, '국민은행': 54, '은행': 417, '대리': 61, '목요일': 4, '목요일날': 1, '접수': 126, '주신': 52, '부분': 338, '결과': 46, '안내': 90, '안내차': 4, '연락': 200, '통화': 125, '제가': 577, '말씀': 248, '현재': 32, '저희': 945, '상품': 93, '서민': 27, '구제': 3, '명목': 3, '정부': 46, '지원': 68, '출시': 7, '기존': 47, '마이너스': 78, '통장': 174, '발급': 119, '조건': 41, '그때': 55, '대신': 22, '신용': 142, '신용대출': 26, '대출': 484, '거래': 88, '이력': 16, '토대': 10, '상황': 76, '지금': 559, '내역': 58, '이용': 110, '중이': 37, '주택': 6, '주택담보대출': 1, '담보': 15, '금융권': 41, '저금리': 16, '때문': 323, '연체': 62, '이제': 232, '원금': 29, '이자': 76, '상환': 269, '사용': 128, '가능': 249, '판단': 14, '자료': 13, '주시': 43, '주시더': 1, '상환능력평가': 6, '능력': 21, '평가': 23, '미달': 9, '부결': 38, '부결처리': 5, '처리': 355, '이것': 220, '심사과': 20, '사과': 27, '기준': 8, '심사': 96, '정확': 42, '결론': 7, '소유': 1, '사람': 83, '일단': 166, '이해': 60, '경우': 145, '거기': 164, '만약': 115, '여부': 6, '조금': 39, '약간': 11, '부족': 19, '부족하다': 3, '하다': 22, '중앙': 3, '중앙교재': 1, '교재': 1, '상담': 71, '시고': 34, '불결': 2, '불결처리': 1, '4대': 11, '보험': 34, '가입': 18, '직장': 22, '재직': 5, '기간': 60, '소득': 28, '금액': 166, '손해': 6, '핸드폰': 32, '요금': 10, '카드': 230, '1번': 83, '3천만': 13, '천만': 100, '생각': 92, '대상자': 3, '선정': 3, '지명목': 1, '통장상품': 1, '기본': 9, '본래': 1, '기본적인': 3, '적인': 10, '워크': 1, '용도': 20, '분양': 1, '투자': 13, '여기': 74, '어디': 98, '주택조합': 1, '조합': 2, '중간': 21, '금리': 111, '한번': 152, '복잡': 4, '이래': 9, '볼려': 1, '거거': 43, '필요': 130, '방법': 83, '확인': 300, '혹시나': 4, '담당': 31, '설계사': 2, '배정': 39, '최대한': 27, '노력': 2, '감사': 94, '220': 4, '220만': 1, '가시': 11, '그거': 200, '그날': 6, '얘기': 148, '50': 22, '50만': 5, '원이요': 8, '이요': 101, '상담원': 17, '50만원': 4, '장바금': 1, '220만원': 1, '취소': 45, '이거': 234, '납부': 137, '일주일': 4, '정도': 205, '소요': 18, '1주일': 11, '주일': 12, '다음': 71, '월요일': 33, '환급': 45, '환급처리': 10, '사이': 16, '전화': 438, '본인': 138, '인증': 20, '어플': 5, '신안': 1, '신안캐피': 1, '캐피': 2, '여행': 2, '리드': 6, '쿠폰': 4, '요새': 1, '금융사': 46, '전부': 13, '명의': 49, '도용': 7, '1글자': 1, '글자': 3, '월요일날': 10, '보이스': 21, '드레': 1, '드레소': 1, '본사': 30, '구의': 1, '구의사항': 1, '사항': 40, '녹음': 12, '담당자': 111, '박성률': 1, '성률': 1, '자동': 27, '송금': 51, '송금처리': 6, '잠시': 105, '제한': 10, '최대': 45, '3900': 1, '3900만원': 1, '최종': 24, '승인': 109, '계좌': 203, '농협': 102, '계약서': 29, '2분': 8, '아가씨': 1, '1분': 5, '보관': 4, '인지': 12, '등록': 35, '같애요': 21, '도와': 18, '담당자분': 10, '절차': 26, '있으신가요': 1, '직전': 1, '양해': 7, '부탁': 22, '사실': 24, '계세': 20, '설명': 85, '담보대출': 5, '마이너스통장': 8, '햇살': 23, '자체': 61, '적용': 19, '변경': 14, '사안': 2, '시간': 140, '고정적': 1, '다행': 3, '대부분': 5, '피해': 14, '금융': 95, '금융법이': 2, '법이': 3, '개정': 3, '고금리': 18, '연체금리': 2, '69': 3, '69프로': 1, '프로': 99, '사채': 3, '수준': 2, '동안': 38, '변동': 23, '만기': 17, '확정': 4, '고정': 10, '도움': 37, '인지세': 7, '협상': 1, '부대': 1, '변동사항': 4, '낮으거': 1, '인제': 15, '공금리': 1, '60': 24, '60프로': 1, '변동금리': 1, '고정금리': 7, '드릴려': 3, '이행': 3, '1시간': 19, '대차': 1, '자금': 298, '10': 64, '10프로': 7, '진행': 359, '390': 1, '390만원': 1, '임기': 1, '부담': 25, '보호': 3, '안전': 16, '대출금': 64, '수령': 41, '전액': 13, '연체이자': 1, '원래': 28, '송구권': 1, '구권': 1, '낙서': 1, '금융감동사회': 1, '감동': 1, '사회': 6, '이적': 1, '나가시': 11, '사용보호소': 1, '보호소': 1, '방문': 53, '서류': 131, '제출': 5, '30': 36, '30분': 18, '현직': 1, '세무': 6, '세무대행표': 1, '대행': 4, '통해': 10, '담당자랑': 4, '자랑': 6, '수록': 1, '동일': 14, '전산': 134, '1가지': 14, '가지': 56, '나중': 36, '임신': 1, '지급': 35, '대로': 31, '삭제': 21, '저번': 4, '환불': 15, '환불금': 1, '손실': 2, '발생': 52, '가면': 9, '전천지': 1, '천지': 1, '부분이요': 3, '정산비': 1, '산비': 1, '보증': 69, '보증보험료': 2, '보험료': 3, '교구': 1, '불법': 14, '편법': 18, '내가': 68, '부재': 3, '부재지면': 1, '지면': 4, '처음': 59, '회비': 2, '친구': 14, '그것': 81, '이때': 3, '그쪽': 126, '1프로': 3, '간호': 1, '수수료': 40, '120': 2, '120만': 1, '금감원': 19, '신고': 57, '제도': 9, '공정': 5, '공정전': 1, '입장': 41, '우리': 139, '소현': 1, '100': 34, '100프로': 7, '고양이': 1, '막말': 2, '아저씨': 8, '잘못': 11, '3자': 3, '이야기': 11, '거잖아': 81, '법적': 18, '당사자': 4, '298': 1, '298만': 1, '27': 3, '27만': 1, '납득': 5, '지하철': 1, '전문': 6, '배송': 7, '업체': 34, '업체구': 1, '물건': 5, '법원': 6, '공탁': 2, '부동산': 4, '자동차': 3, '매매': 3, '매매매입': 1, '매입': 8, '인테리어': 1, '견적': 2, '서류배송': 1, '일당': 1, '당 ...

# %%
# 값(value)에 따라 내림차순으로 정렬하여 상위 20개의 아이템을 추출
dic = dict(sorted(dic.items(), key=lambda x: x[1], reverse=True)[:100])

print(dic)
# Out:
# {'고객': 1550, '저희': 945, '제가': 577, '지금': 559, '대출': 484, '전화': 438, '은행': 417, '진행': 359, '처리': 355, '부분': 338, '때문': 323, '확인': 300, '자금': 298, '상환': 269, '가능': 249, '말씀': 248, '이거': 234, '이제': 232, '카드': 230, '이것': 220, '정도': 205, '계좌': 203, '연락': 200, '그거': 200, '통장': 174, '번호': 173, '일단': 166, '금액': 166, '거기': 164, '한번': 152, '얘기': 148, '경우': 145, '신용': 142, '시간': 140, '우리': 139, '본인': 138, '납부': 137, '전산': 134, '서류': 131, '필요': 130, '사용': 128, '오늘': 127, '접수': 126, '그쪽': 126, '통화': 125, '한도': 120, '발급': 119, '만약': 115, '금리': 111, '담당자': 111, '이용': 110, '승인': 109, '입금': 106, '잠시': 105, '농협': 102, '이요': 101, '천만': 100, '프로': 99, '국민': 98, '어디': 98, '하나': 98, '심사': 96, '금융': 95, '감사': 94, '신청': 94, '상품': 93, '생각': 92, '이상': 91, '안내': 90, '거래': 88, '직원': 86, '설명': 85, '개월': 85, '저축': 84, '사람': 83, '1번': 83, '방법': 83, '그것': 81, '거잖아': 81, '얼마': 81, '거구': 79, '마이너스': 78, '상황': 76, '이자': 76, '여기': 74, '요청': 74, '내일': 72, '문제': 72, '상담': 71, '다음': 71, '관리': 70, '보증': 69, '하면': 69, '지원': 68, '내가': 68, '10': 64, '대출금': 64, '비용': 64, '캐피탈': 64, '회사': 64}

# %%
del dic['제가']
del dic['지금']
del dic['때문']
del dic['이거']
del dic['이제']
del dic['이것']
del dic['그거']
del dic['거기']
del dic['우리']
del dic['오늘']
del dic['그쪽']
del dic['이요']
del dic['어디']
del dic['그것']
del dic['여기']

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# %%
wc = WordCloud(background_color="white", 
               font_path = "BMDOHYEON_ttf.ttf",
               colormap = "Blues").generate_from_frequencies(dic)
plt.axis('off')
plt.imshow(wc)
plt.show()

# %%
from PIL import Image
import numpy as np

# %%
image = Image.open('dollarsign2.jpg')
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=894x894>

# %%
image2 = np.array(image) # 이미지를 행렬로 바꿔라.
image2
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
wc = WordCloud(background_color="white", 
               font_path = "BMDOHYEON_ttf.ttf",
               colormap = "Greens",
                mask = image2).generate_from_frequencies(dic)
               
plt.axis('off')
plt.imshow(wc)
plt.show()
